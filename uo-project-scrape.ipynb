# %%
import pandas as pd

data = pd.read_csv('makerepo-pages-data.csv').drop('Unnamed: 0', axis=1)
data
# Out:
#                                                     Url  \
# 0     https://makerepo.com/akari033/2100.basic-train...
# 1                   https://makerepo.com/zay/2099.car\n
# 2        https://makerepo.com/jboud030/2098.moo-money\n
# 3       https://makerepo.com/jboud030/2097.invisifall\n
# 4     https://makerepo.com/jboud030/2096.move-it-cal...
# ...                                                 ...
# 1403  https://makerepo.com/mshor046/net-zero-home-wa...
# 1404  https://makerepo.com/okemp031/herb-reserve-gng...
# 1405  https://makerepo.com/acope014/aquatic-seed-lau...
# 1406  https://makerepo.com/pbarr083/fire-notificatio...
# 1407     https://makerepo.com/pduiv079/steady-utensil\n
#
#                                         Title         Date  \
# 0                      Basic Training Pre-lab  Sep 22 2024
# 1                                         car  Aug 29 2024
# 2                                   Moo Money   Aug 8 2024
# ...
